# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder

# %%
dataset = pd.read_csv(r"C:\Users\sscomputers\Desktop\30 Days\Day 4\Customer Churn.csv")
dataset.head(3)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# ...

# %%
encoder = LabelEncoder()
dataset["gender"] = encoder.fit_transform(dataset["gender"])

# %%
# dataset["Partner"].head(5)
dataset["Partner"].unique()
dataset["Partner"] = encoder.fit_transform(dataset["Partner"])
dataset["Partner"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 7038    1
# 7039    1
# 7040    1
# 7041    1
# 7042    0
# Name: Partner, Length: 7043, dtype: int32

# %%
dataset
# Out:
#       customerID  gender  SeniorCitizen  Partner Dependents  tenure  \
# 0     7590-VHVEG       0              0        1         No       1
# 1     5575-GNVDE       1              0        0         No      34
# 2     3668-QPYBK       1              0        0         No       2
# 3     7795-CFOCW       1              0        0         No      45
# 4     9237-HQITU       0              0        0         No       2
# ...          ...     ...            ...      ...        ...     ...
# 7038  6840-RESVB       1              0        1        Yes      24
# 7039  2234-XADUH       0              0        1        Yes      72
# 7040  4801-JZAZL       0              0        1        Yes      11
# 7041  8361-LTMKD       1              1        1         No       4
# 7042  3186-AJIEK       1              0        0         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
columns = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
    'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
    'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

new = []

for column in columns:
    if dataset[column].dtype == "object":
        if dataset[column].nunique() == 2:
            new.append(column)

# %%
col = ['Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']
for c in col:
    dataset[c] = dataset[c].map({"Yes" : 1, "No" : 0})

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   int32
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   int32
#  4   Dependents        7043 non-null   int64
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   int64
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
columns = ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
    'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
    'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
    'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
    'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']

new = []

for column in columns:
    if dataset[column].dtype == "object":
        new.append(column)
print(new)
# Out:
# ['customerID', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod', 'TotalCharges']

# %%
cols = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod', 'TotalCharges']

for col in cols:
    print(f"The Column name is: {col}, and unique value is {dataset[col].unique()}, and num of uniques {dataset[col].nunique()}")
# Out:
# The Column name is: MultipleLines, and unique value is ['No phone service' 'No' 'Yes'], and num of uniques 3
# The Column name is: InternetService, and unique value is ['DSL' 'Fiber optic' 'No'], and num of uniques 3
# The Column name is: OnlineSecurity, and unique value is ['No' 'Yes' 'No internet service'], and num of uniques 3
# The Column name is: OnlineBackup, and unique value is ['Yes' 'No' 'No internet service'], and num of uniques 3
# The Column name is: DeviceProtection, and unique value is ['No' 'Yes' 'No internet service'], and num of uniques 3
# The Column name is: TechSupport, and unique value is ['No' 'Yes' 'No internet service'], and num of uniques 3
# The Column name is: StreamingTV, and unique value is ['No' 'Yes' 'No internet service'], and num of uniques 3
# The Column name is: StreamingMovies, and unique value is ['No' 'Yes' 'No internet service'], and num of uniques 3
# ...

# %%
cols = ['MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaymentMethod']

for col in cols:
    unique = dataset[col].unique()
    
    mapping = {v: i for i, v in enumerate(unique)}
    dataset[col] = dataset[col].map(mapping)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int64
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int64
#  6   MultipleLines     7043 non-null   int64
#  7   InternetService   7043 non-null   int64
#  8   OnlineSecurity    7043 non-null   int64
#  9   OnlineBackup      7043 non-null   int64
#  10  DeviceProtection  7043 non-null   int64
#  11  TechSupport       7043 non-null   int64
#  12  StreamingTV       7043 non-null   int64
#  13  StreamingMovies   7043 non-null   int64
#  14  Contract          7043 non-null   int64
#  15  PaperlessBilling  7043 non-null   int64
# ...

# %%
dataset.drop('customerID', axis=1, inplace=True)

# %%
dataset["TotalCharges"].nunique()
# Out:
# 6531

# %%
dataset["TotalCharges"] = pd.to_numeric(dataset["TotalCharges"], errors = "coerce")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int32
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   int32
#  3   Dependents        7043 non-null   int64
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   int64
#  6   MultipleLines     7043 non-null   int64
#  7   InternetService   7043 non-null   int64
#  8   OnlineSecurity    7043 non-null   int64
#  9   OnlineBackup      7043 non-null   int64
#  10  DeviceProtection  7043 non-null   int64
#  11  TechSupport       7043 non-null   int64
#  12  StreamingTV       7043 non-null   int64
#  13  StreamingMovies   7043 non-null   int64
#  14  Contract          7043 non-null   int64
#  15  PaperlessBilling  7043 non-null   int64
# ...

# %%
x = dataset.drop("Churn", axis = 1)
Y = dataset["Churn"]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, Y, test_size = 0.20, random_state = 42)

# %%
x_test
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 185        0              0        1           0       1             0
# 2715       1              0        0           0      41             1
# 3825       0              0        1           1      52             1
# 1807       0              0        0           0       1             1
# 132        1              0        0           0      67             1
# ...      ...            ...      ...         ...     ...           ...
# 6366       0              0        1           0      64             1
# 315        1              0        1           1      51             1
# 2439       1              0        1           1      17             1
# 5002       0              0        1           1      69             0
# 1161       1              0        0           1       1             0
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...
